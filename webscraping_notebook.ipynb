# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns; sns.set_style('ticks')

import re
from unicodedata import normalize

import requests as rq
from bs4 import BeautifulSoup as bs
from selenium import webdriver


import time
import pickle

from functions import *

# %load_ext autoreload
# %autoreload 2

# %%
page = rq.get('https://top40weekly.com/1960-all-charts/')
soup = bs(page.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="https://top40weekly.com/xmlrpc.php" rel="pingback"/>
# <script>
# window.adthrive = window.adthrive || {};
# window.adthrive.cmd = window.adthrive.cmd || [];
# window.adthrive.host = 'ads.adthrive.com';
# window.adthrive.plugin = 'adthrive-ads-1.0.37';
# window.adthrive.threshold = Math.floor(Math.random() * 100 + 1);
#
# (function() {
# 	var script = document.createElement('script');
# 	script.async = true;
# 	script.type = 'text/javascript';
# 	script.src = 'https://ads.adthrive.com/sites/5cacd09cb13d6c3ef8c8bbde/ads.min.js?threshold=' + window.adthrive.threshold;
# 	var node = document.getElementsByTagName('script')[0];
# 	node.parentNode.insertBefore(script, node);
# })();
# </script>
# <!-- Jetpack Site Verification Tags -->
# ...

# %%
test = soup.find_all('p')
test
# Out:
# [<p>Check out our partner website Singles Chronology for all the <a href="https://singleschronology.com/1960-2/" rel="noopener noreferrer" target="_blank">Hot 100 releases for 1960</a>.</p>,
# ...

# %%
test[1].contents
# Out:
# [<a href="https://top40weekly.com/1960-all-charts/frankie-avalon-why-1959/" rel="attachment wp-att-9501"><img alt="frankie-avalon-why-1959" class="alignnone size-medium wp-image-9501" data-attachment-id="9501" data-comments-opened="0" data-image-description="" data-image-meta='{"aperture":"0","credit":"","camera":"","caption":"","created_timestamp":"0","copyright":"","focal_length":"0","iso":"0","shutter_speed":"0","title":"","orientation":"0"}' data-image-title="frankie-avalon-why-1959" data-large-file="https://i1.wp.com/top40weekly.com/wp-content/uploads/1960/12/frankie-avalon-why-1959.jpg?fit=750%2C749&amp;ssl=1" data-medium-file="https://i1.wp.com/top40weekly.com/wp-content/uploads/1960/12/frankie-avalon-why-1959.jpg?fit=300%2C300&amp;ssl=1" data-orig-file="https://i1.wp.com/top40weekly.com/wp-content/uploads/1960/12/frankie-avalon-why-1959.jpg?fit=799%2C798&amp;ssl=1" data-orig-size="799,798" data-permalink="https://top40weekly.com/1960-all-charts/frankie-avalon-why-1959/" data-
# ...

# %%
len(test[1].contents)
# Out:
# 89

# %%
len(test[10].contents)
# Out:
# 85

# %%
weeks = [week.contents for week in test if len(week.contents) > 80]
weeks
# Out:
# [[<a href="https://top40weekly.com/1960-all-charts/frankie-avalon-why-1959/" rel="attachment wp-att-9501"><img alt="frankie-avalon-why-1959" class="alignnone size-medium wp-image-9501" data-attachment-id="9501" data-comments-opened="0" data-image-description="" data-image-meta='{"aperture":"0","credit":"","camera":"","caption":"","created_timestamp":"0","copyright":"","focal_length":"0","iso":"0","shutter_speed":"0","title":"","orientation":"0"}' data-image-title="frankie-avalon-why-1959" data-large-file="https://i1.wp.com/top40weekly.com/wp-content/uploads/1960/12/frankie-avalon-why-1959.jpg?fit=750%2C749&amp;ssl=1" data-medium-file="https://i1.wp.com/top40weekly.com/wp-content/uploads/1960/12/frankie-avalon-why-1959.jpg?fit=300%2C300&amp;ssl=1" data-orig-file="https://i1.wp.com/top40weekly.com/wp-content/uploads/1960/12/frankie-avalon-why-1959.jpg?fit=799%2C798&amp;ssl=1" data-orig-size="799,798" data-permalink="https://top40weekly.com/1960-all-charts/frankie-avalon-why-1959/" data
# ...

# %%
len(weeks)
# Out:
# 51

# %%
weeks_updated = [[str(line) for line in week if str(line) != '<br/>' if str(line) != '\n——'] for week in weeks]
print(len(weeks_updated))
weeks_updated
# Out:
# 51
# ...

# %%
weeks_updated = [[' ' + str(line) for line in week if str(line) != '<br/>' if str(line) != '\n——'] for week in weeks]
print(len(weeks_updated))
weeks_updated
# Out:
# 51
# ...

# %%
pattern = r'\s{1,2}(?:[1-9]|0[1-9]|10) [1-9][0-9]? ([\w\s\.,’“”\(\)\–\-]+) –•– ([A-Za-z\s,]+)'
top10s = [[(re.match(pattern, line).group(1).strip(), re.match(pattern, line).group(2).strip()) for line in week if re.match(pattern, line)] for week in weeks_updated]

# [(re.match(pattern, line).group(1).strip(), re.match(pattern, line).group(2).strip()) \
#           for week in weeks for line in week]

# %%
len(top10s)
# Out:
# 51

# %%
weeks_updated[-1]
# Out:
# [' 1 1 ARE YOU LONESOME TO-NIGHT –•– Elvis Presley (RCA Victor)-6 (4 weeks at #1) (1)',
#  ' \n2 2 LAST DATE –•– Floyd Cramer (RCA Victor)-11 (2)',
#  ' \n3 4 WONDERLAND BY NIGHT –•– Bert Kaempfert (Decca)-6 (3)',
#  ' \n4 5 NORTH TO ALASKA –•– Johnny Horton (Columbia)-14 (4)',
#  ' \n5 6 SAILOR (Your Home Is the Sea) –•– Lolita (Kapp)-9 (5)',
#  ' \n6 10 EXODUS –•– Ferrante and Teicher (United Artists)-6 (6)',
#  ' \n7 3 A THOUSAND STARS –•– Kathy Young and the Innocents (Indigo)-9 (3)',
#  ' \n8 8 MANY TEARS AGO –•– Connie Francis (MGM)-7 (8)',
#  ' \n9 12 YOU’RE SIXTEEN –•– Johnny Burnette (Liberty)-8 (9)',
#  ' \n10 7 HE WILL BREAK YOUR HEART –•– Jerry Butler (Vee-Jay)-8 (7)',
#  ' \n11 9 POETRY IN MOTION –•– Johnny Tillotson (Cadence)-11 (2)',
#  ' \n12 18 LONELY TEENAGER –•– Dion (Laurie)-10 (12)',
#  ' \n13 11 STAY –•– Maurice Williams and the Zodiacs (Herald)-12 (1)',
#  ' \n14 14 SWAY –•– Bobby Rydell (Cameo)-7 (14)',
# ...

# %%
top10s[-1]
# Out:
# [('ARE YOU LONESOME TO-NIGHT', 'Elvis Presley'),
#  ('LAST DATE', 'Floyd Cramer'),
#  ('WONDERLAND BY NIGHT', 'Bert Kaempfert'),
#  ('NORTH TO ALASKA', 'Johnny Horton'),
#  ('SAILOR (Your Home Is the Sea)', 'Lolita'),
#  ('EXODUS', 'Ferrante and Teicher'),
#  ('A THOUSAND STARS', 'Kathy Young and the Innocents'),
#  ('MANY TEARS AGO', 'Connie Francis'),
#  ('YOU’RE SIXTEEN', 'Johnny Burnette'),
#  ('HE WILL BREAK YOUR HEART', 'Jerry Butler')]

# %%
for week in top10s:
    print(len(week))
# Out:
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10

# %%
pattern = r'\s(?:[1-9]|0[1-9]|10) [1-9][0-9]? ([\w\s\.,’\(\)]+) –•– ([A-Za-z\s,]+)'
top10s_set = set((re.match(pattern, line).group(1).strip(), re.match(pattern, line).group(2).strip()) \
          for week in weeks_updated for line in week if re.match(pattern, line))

# %%
len(top10s_set)
# Out:
# 97

# %%
print(len(top10s))
top10s

# %%
[(re.match(pattern, line).group(1).strip(), re.match(pattern, line).group(2).strip()) \
 for line in lines_trimmed if re.match(pattern, line)]

# %%
[val for sublist in matrix for val in sublist]

# %%
pattern = r'\s(?:[1-9]|0[1-9]|10) [1-9][0-9]? ([\w\s\.,’\(\)]+) –•– ([A-Za-z\s,]+)'
lines = [str(line) for line in test[1].contents if str(line) != '<br/>']
lines
# [re.search(pattern, line, re.I).group(1).splitlines() for line in lines]
# Out:
# ['<a href="https://top40weekly.com/1960-all-charts/frankie-avalon-why-1959/" rel="attachment wp-att-9501"><img alt="frankie-avalon-why-1959" class="alignnone size-medium wp-image-9501" data-attachment-id="9501" data-comments-opened="0" data-image-description="" data-image-meta=\'{"aperture":"0","credit":"","camera":"","caption":"","created_timestamp":"0","copyright":"","focal_length":"0","iso":"0","shutter_speed":"0","title":"","orientation":"0"}\' data-image-title="frankie-avalon-why-1959" data-large-file="https://i1.wp.com/top40weekly.com/wp-content/uploads/1960/12/frankie-avalon-why-1959.jpg?fit=750%2C749&amp;ssl=1" data-medium-file="https://i1.wp.com/top40weekly.com/wp-content/uploads/1960/12/frankie-avalon-why-1959.jpg?fit=300%2C300&amp;ssl=1" data-orig-file="https://i1.wp.com/top40weekly.com/wp-content/uploads/1960/12/frankie-avalon-why-1959.jpg?fit=799%2C798&amp;ssl=1" data-orig-size="799,798" data-permalink="https://top40weekly.com/1960-all-charts/frankie-avalon-why-1959/" da
# ...

# %%
lines_trimmed = lines[2:12]
lines_trimmed
# Out:
# ['\n1 2 WHY –•– Frankie Avalon (Chancellor)-6 (1 week at #1) (1)',
#  '\n2 3 EL PASO –•– Marty Robbins (Columbia)-8 (2)',
#  '\n3 4 THE BIG HURT –•– Miss Toni Fisher (Signet)-7 (3)',
#  '\n4 6 IT’S TIME TO CRY –•– Paul Anka (ABC-Paramount)-6 (4)',
#  '\n5 5 WAY DOWN YONDER IN NEW ORLEANS –•– Freddy Cannon (Swan)-6 (5)',
#  '\n6 1 HEARTACHES BY THE NUMBER –•– Guy Mitchell (Columbia)-13 (1)',
#  '\n7 9 AMONG MY SOUVENIRS –•– Connie Francis (MGM)-6 (7)',
#  '\n8 7 MACK THE KNIFE –•– Bobby Darin (Atco)-19 (1)',
#  '\n9 10 HOUND DOG MAN –•– Fabian (Chancellor)-7 (9)',
#  '\n10 19 PRETTY BLUE EYES –•– Steve Lawrence (ABC-Paramount)-6 (10)']

# %%
(re.match(pattern, lines[5]).group(1).strip(), re.match(pattern, lines[5]).group(2).strip())
# Out:
# ('IT’S TIME TO CRY', 'Paul Anka')

# %%
lines[2]
# Out:
# '\n1 2 WHY –•– Frankie Avalon (Chancellor)-6 (1 week at #1) (1)'

# %%
top10_regex_not_100 = [(re.match(pattern, line).group(1).strip(), re.match(pattern, line).group(2).strip()) for line in lines if re.match(pattern, line)]
top10_regex_not_100
# Out:
# [('WHY', 'Frankie Avalon'),
#  ('EL PASO', 'Marty Robbins'),
#  ('THE BIG HURT', 'Miss Toni Fisher'),
#  ('IT’S TIME TO CRY', 'Paul Anka'),
#  ('WAY DOWN YONDER IN NEW ORLEANS', 'Freddy Cannon'),
#  ('HEARTACHES BY THE NUMBER', 'Guy Mitchell'),
#  ('AMONG MY SOUVENIRS', 'Connie Francis'),
#  ('MACK THE KNIFE', 'Bobby Darin'),
#  ('HOUND DOG MAN', 'Fabian'),
#  ('PRETTY BLUE EYES', 'Steve Lawrence')]

# %%
top10 = [(re.match(pattern, line).group(1).strip(), re.match(pattern, line).group(2).strip()) for line in lines_trimmed if re.match(pattern, line)]
top10
# Out:
# [('WHY', 'Frankie Avalon'),
#  ('EL PASO', 'Marty Robbins'),
#  ('THE BIG HURT', 'Miss Toni Fisher'),
#  ('IT’S TIME TO CRY', 'Paul Anka'),
#  ('WAY DOWN YONDER IN NEW ORLEANS', 'Freddy Cannon'),
#  ('HEARTACHES BY THE NUMBER', 'Guy Mitchell'),
#  ('AMONG MY SOUVENIRS', 'Connie Francis'),
#  ('MACK THE KNIFE', 'Bobby Darin'),
#  ('HOUND DOG MAN', 'Fabian'),
#  ('PRETTY BLUE EYES', 'Steve Lawrence')]

# %%
{'p': re.compile(r'\s[1-9][0]? [1-9][0-9]? ([\w\s\.,’\(\)]+) –•– ([A-Za-z\s,]+)')}
